# %%
import matplotlib.pyplot as plt
import numpy as np

datos = [0.9,  2. ,  3.6,  5.6,  8. , 10.9, 14.2, 18.]
datos_7 = [0.3,  1.7,  4.1,  5.7,  8.5, 10.7, 13.6, 17.2]

#Grafica estudiante nota 1
plt.errorbar(np.arange(0,8),datos,yerr=0.4,ecolor="red")
plt.title("Gráfica estudiante nota 1")
plt.xlabel("Tiempo")
plt.ylabel("Posición(cm)")
plt.show()

#Graficaestudiante nota 7
plt.errorbar(np.arange(0,8),datos_7,yerr=0.4,ecolor="red")
plt.title("Gráfica alumno nota 7")
plt.xlabel("Tiempo")
plt.ylabel("Posición(cm)")
plt.show()

#Al comprarar los resultados, se observa que los datos del alumno con nota 1 ajustan demasiado bien al valor teorico esperado (parábola) para un
#instrumento con un error instrumental tan grande, lo que sugiere que los datos no fueron tomados en una medida real (han sido falsificados.)

#pd: profe le había mandado un correo, tenia una duda con esta tarea, por eso el retraso.

# %% [markdown]
# # Calficación: 6.0
#
# -1.0 por el retraso en la entrega.
